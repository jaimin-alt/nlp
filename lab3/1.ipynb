# %%
import collections

# --- Trie Node and Base Class ---
class TrieNode:
    def __init__(self):
        self.children = collections.defaultdict(TrieNode)
        self.is_end_of_word = False
        self.count = 0

class Trie:
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word: str):
        node = self.root
        for char in word:
            node = node.children[char]
            node.count += 1
        node.is_end_of_word = True

    def find_stem_suffix(self, word: str) -> (str, str):
        node = self.root
        best_split_point = 0
        max_score = -1

        for i, char in enumerate(word):
            if char not in node.children:
                return word, ""
            node = node.children[char]
            
            # A node is a potential split point if it branches OR it's a valid word itself.
            is_potential_split = (len(node.children) > 1 or node.is_end_of_word)
            
            # The score is the node's frequency. Higher frequency means a more common stem.
            score = node.count

            # We look for the best score at a potential split point.
            if is_potential_split and score > max_score and i < len(word) - 1:
                max_score = score
                best_split_point = i + 1
        
        if best_split_point == 0:
            return word, ""

        stem = word[:best_split_point]
        suffix = word[best_split_point:]
        return stem, suffix

# --- Prefix Trie Implementation ---
class PrefixTrie(Trie):
    def analyze_word(self, word: str):
        return self.find_stem_suffix(word)

# --- Suffix Trie Implementation ---
class SuffixTrie(Trie):
    def insert(self, word: str):
        super().insert(word[::-1])

    def analyze_word(self, word: str):
        reversed_word = word[::-1]
        rev_head, rev_tail = self.find_stem_suffix(reversed_word)
        
        # The reversed "head" of the reversed word is the suffix
        suffix = rev_head[::-1]
        # The reversed "tail" of the reversed word is the stem
        stem = rev_tail[::-1]
        
        return stem, suffix

# --- Main Execution ---
def run_full_analysis(filename="brown_nouns.txt"):
    """
    Reads all nouns from the file, analyzes them with both tries,
    and prints the complete results.
    """
    try:
        with open(filename, 'r') as f:
            words_from_file = [line.strip().lower() for line in f if line.strip()]

            # --- THE FIX IS HERE ---
            # Filter the list to include only alphabetic words
            words = sorted(list(set([
                word for word in words_from_file if word.isalpha()
            ])))
            # --- END OF FIX ---

    except FileNotFoundError:
        print(f"Error: '{filename}' not found. Please place it in the same directory.")
        return

    # (The rest of the function remains the same)
    ...

    # Initialize and populate tries
    prefix_trie = PrefixTrie()
    suffix_trie = SuffixTrie()
    for word in words:
        prefix_trie.insert(word)
        suffix_trie.insert(word)

    print("--- Full Analysis Results from brown_nouns.txt ---")
    print("Word".ljust(20), "PrefixTrie".ljust(25), "SuffixTrie".ljust(25))
    print("-" * 70)

    # Iterate over the complete list of words from the file
    for word in words:
        p_stem, p_suffix = prefix_trie.analyze_word(word)
        s_stem, s_suffix = suffix_trie.analyze_word(word)
        
        p_out = f"{p_stem}+{p_suffix}" if p_suffix else p_stem
        s_out = f"{s_stem}+{s_suffix}" if s_suffix else s_stem
        
        print(word.ljust(20), p_out.ljust(25), s_out.ljust(25))


if __name__ == "__main__":
    run_full_analysis()
# Out:
# --- Full Analysis Results from brown_nouns.txt ---
# Word                 PrefixTrie                SuffixTrie
# ----------------------------------------------------------------------
# aaa                  a+aa                      aa+a
# abandon              a+bandon                  abando+n
# abandonment          a+bandonment              abandonmen+t
# abaringe             a+baringe                 abaring+e
# abasement            a+basement                abasemen+t
# abberations          a+bberations              abberation+s
# abbey                a+bbey                    abbe+y
# abbot                a+bbot                    abbo+t
# abbreviation         a+bbreviation             abbreviatio+n
# abbreviations        a+bbreviations            abbreviation+s
# abdomen              a+bdomen                  abdome+n
# abdominis            a+bdominis                abdomini+s
# abduction            a+bduction                abductio+n
# aberration           a+berration               aberratio+n
# aberrations          a+berrations              aberration+s
# abeyance             a+beyance                 abeyanc+e
# abilities            a+bilities                abilitie+s
# ability              a+bility                  abilit+y
# abjection            a+bjection                abjectio+n
# ablation             a+blation                 ablatio+n
# abnormalities        a+bnormalities            abnormalitie+s
# abo                  a+bo                      ab+o
# abode                a+bode                    abod+e
# abolition            a+bolition                abolitio+n
# abolitionist         a+bolitionist             abolitionis+t
# abolitionists        a+bolitionists            abolitionist+s
# aborigine            a+borigine                aborigin+e
# aborigines           a+borigines               aborigine+s
# abortion             a+bortion                 abortio+n
# abortions            a+bortions                abortion+s
# abreaction           a+breaction               abreactio+n
# abridgment           a+bridgment               abridgmen+t
# abruptness           a+bruptness               abruptnes+s
# abscesses            a+bscesses                abscesse+s
# abscissa             a+bscissa                 absciss+a
# absence              a+bsence                  absenc+e
# absences             a+bsences                 absence+s
# absentee             a+bsentee                 absente+e
# absenteeism          a+bsenteeism              absenteeis+m
# absentia             a+bsentia                 absenti+a
# absinthe             a+bsinthe                 absinth+e
# absolute             a+bsolute                 absolut+e
# absoluteness         a+bsoluteness             absolutenes+s
# absolutes            a+bsolutes                absolute+s
# absolution           a+bsolution               absolutio+n
# absorbency           a+bsorbency               absorbenc+y
# absorber             a+bsorber                 absorbe+r
# absorption           a+bsorption               absorptio+n
# absorptions          a+bsorptions              absorption+s
# abstention           a+bstention               abstentio+n
# abstinence           a+bstinence               abstinenc+e
# abstract             a+bstract                 abstrac+t
# abstractedness       a+bstractedness           abstractednes+s
# abstraction          a+bstraction              abstractio+n
# abstractionism       a+bstractionism           abstractionis+m
# abstractionists      a+bstractionists          abstractionist+s
# abstractions         a+bstractions             abstraction+s
# abstractors          a+bstractors              abstractor+s
# abstracts            a+bstracts                abstract+s
# abstrusenesses       a+bstrusenesses           abstrusenesse+s
# absurdities          a+bsurdities              absurditie+s
# absurdity            a+bsurdity                absurdit+y
# abundance            a+bundance                abundanc+e
# abuse                a+buse                    abus+e
# abuses               a+buses                   abuse+s
# abutments            a+butments                abutment+s
# abyss                a+byss                    abys+s
# acacia               a+cacia                   acaci+a
# academeh             a+cademeh                 academe+h
# academic             a+cademic                 academi+c
# academics            a+cademics                academic+s
# academies            a+cademies                academie+s
# academy              a+cademy                  academ+y
# acceleration         a+cceleration             acceleratio+n
# accelerations        a+ccelerations            acceleration+s
# accelerator          a+ccelerator              accelerato+r
# accelerators         a+ccelerators             accelerator+s
# accelerometer        a+ccelerometer            acceleromete+r
# accelerometers       a+ccelerometers           accelerometer+s
# accent               a+ccent                   accen+t
# accenting            a+ccenting                accentin+g
# accents              a+ccents                  accent+s
# acceptability        a+cceptability            acceptabilit+y
# acceptance           a+cceptance               acceptanc+e
# access               a+ccess                   acces+s
# accesses             a+ccesses                 accesse+s
# accessibility        a+ccessibility            accessibilit+y
# accessions           a+ccessions               accession+s
# accessories          a+ccessories              accessorie+s
# accessory            a+ccessory                accessor+y
# accident             a+ccident                 acciden+t
# accidents            a+ccidents                accident+s
# acclaim              a+cclaim                  acclai+m
# acclamation          a+cclamation              acclamatio+n
# accolade             a+ccolade                 accolad+e
# accolades            a+ccolades                accolade+s
# accommodation        a+ccommodation            accommodatio+n
# accommodations       a+ccommodations           accommodation+s
# accomodations        a+ccomodations            accomodation+s
# accompaniment        a+ccompaniment            accompanimen+t
# accompaniments       a+ccompaniments           accompaniment+s
# accompanist          a+ccompanist              accompanis+t
# accompanists         a+ccompanists             accompanist+s
# accomplice           a+ccomplice               accomplic+e
# accomplices          a+ccomplices              accomplice+s
# accomplishment       a+ccomplishment           accomplishmen+t
# accomplishments      a+ccomplishments          accomplishment+s
# accord               a+ccord                   accor+d
# accordance           a+ccordance               accordanc+e
# accordion            a+ccordion                accordio+n
# account              a+ccount                  accoun+t
# accountability       a+ccountability           accountabilit+y
# accountant           a+ccountant               accountan+t
# accountants          a+ccountants              accountant+s
# accounting           a+ccounting               accountin+g
# accounts             a+ccounts                 account+s
# accouterments        a+ccouterments            accouterment+s
# accreditation        a+ccreditation            accreditatio+n
# accretion            a+ccretion                accretio+n
# accretions           a+ccretions               accretion+s
# acculturation        a+cculturation            acculturatio+n
# accumulation         a+ccumulation             accumulatio+n
# accuracy             a+ccuracy                 accurac+y
# accusation           a+ccusation               accusatio+n
# accusations          a+ccusations              accusation+s
# ace                  a+ce                      ac+e
# aces                 a+ces                     ace+s
# acetate              a+cetate                  acetat+e
# acetone              a+cetone                  aceton+e
# acetonemia           a+cetonemia               acetonemi+a
# ache                 a+che                     ach+e
# achievement          a+chievement              achievemen+t
# achievements         a+chievements             achievement+s
# acid                 a+cid                     aci+d
# acidity              a+cidity                  acidit+y
# acids                a+cids                    acid+s
# acknowledgement      a+cknowledgement          acknowledgemen+t
# acknowledgment       a+cknowledgment           acknowledgmen+t
# acknowledgments      a+cknowledgments          acknowledgment+s
# acolyte              a+colyte                  acolyt+e
# aconte               a+conte                   acont+e
# acorns               a+corns                   acorn+s
# acoustics            a+coustics                acoustic+s
# acquaintance         a+cquaintance             acquaintanc+e
# acquiescence         a+cquiescence             acquiescenc+e
# acquiesence          a+cquiesence              acquiesenc+e
# acquisition          a+cquisition              acquisitio+n
# acquisitions         a+cquisitions             acquisition+s
# acquisitiveness      a+cquisitiveness          acquisitivenes+s
# acquittal            a+cquittal                acquitta+l
# acre                 a+cre                     acr+e
# acreage              a+creage                  acreag+e
# acres                a+cres                    acre+s
# acrobacy             a+crobacy                 acrobac+y
# acrobatics           a+crobatics               acrobatic+s
# acrobats             a+crobats                 acrobat+s
# acrylic              a+crylic                  acryli+c
# act                  a+ct                      ac+t
# acting               a+cting                   actin+g
# actinometer          a+ctinometer              actinomete+r
# action               a+ction                   actio+n
# actions              a+ctions                  action+s
# activation           a+ctivation               activatio+n
# active               a+ctive                   activ+e
# actives              a+ctives                  active+s
# activism             a+ctivism                 activis+m
# activities           a+ctivities               activitie+s
# activity             a+ctivity                 activit+y
# actor                a+ctor                    acto+r
# actors               a+ctors                   actor+s
# actress              a+ctress                  actres+s
# actresses            a+ctresses                actresse+s
# acts                 a+cts                     act+s
# actualities          a+ctualities              actualitie+s
# actuality            a+ctuality                actualit+y
# acumen               a+cumen                   acume+n
# adage                a+dage                    adag+e
# adagio               a+dagio                   adagi+o
# adagios              a+dagios                  adagio+s
# adaptation           a+daptation               adaptatio+n
# adaptations          a+daptations              adaptation+s
# adapter              a+dapter                  adapte+r
# adapters             a+dapters                 adapter+s
# adapting             a+dapting                 adaptin+g
# adc                  a+dc                      ad+c
# addiction            a+ddiction                addictio+n
# addicts              a+ddicts                  addict+s
# adding               a+dding                   addin+g
# addition             a+ddition                 additio+n
# additions            a+dditions                addition+s
# additive             a+dditive                 additiv+e
# additives            a+dditives                additive+s
# address              a+ddress                  addres+s
# addressees           a+ddressees               addressee+s
# addresses            a+ddresses                addresse+s
# adenomas             a+denomas                 adenoma+s
# adequacy             a+dequacy                 adequac+y
# adherence            a+dherence                adherenc+e
# adherent             a+dherent                 adheren+t
# adherents            a+dherents                adherent+s
# adhesion             a+dhesion                 adhesio+n
# adhesive             a+dhesive                 adhesiv+e
# adhesives            a+dhesives                adhesive+s
# adjective            a+djective                adjectiv+e
# adjectives           a+djectives               adjective+s
# adjournment          a+djournment              adjournmen+t
# adjudication         a+djudication             adjudicatio+n
# adjunct              a+djunct                  adjunc+t
# adjuncts             a+djuncts                 adjunct+s
# adjustment           a+djustment               adjustmen+t
# adjustments          a+djustments              adjustment+s
# administration       a+dministration           administratio+n
# administrator        a+dministrator            administrato+r
# administrators       a+dministrators           administrator+s
# adminstration        a+dminstration            adminstratio+n
# admirals             a+dmirals                 admiral+s
# admiralty            a+dmiralty                admiralt+y
# admiration           a+dmiration               admiratio+n
# admirer              a+dmirer                  admire+r
# admirers             a+dmirers                 admirer+s
# admission            a+dmission                admissio+n
# admissions           a+dmissions               admission+s
# admittance           a+dmittance               admittanc+e
# admonishments        a+dmonishments            admonishment+s
# admonition           a+dmonition               admonitio+n
# admonitions          a+dmonitions              admonition+s
# adobe                a+dobe                    adob+e
# adolescence          a+dolescence              adolescenc+e
# adolescent           a+dolescent               adolescen+t
# adolescents          a+dolescents              adolescent+s
# adoption             a+doption                 adoptio+n
# adrenal              a+drenal                  adrena+l
# adroitness           a+droitness               adroitnes+s
# ads                  a+ds                      ad+s
# adulation            a+dulation                adulatio+n
# adult                a+dult                    adul+t
# adulterers           a+dulterers               adulterer+s
# adultery             a+dultery                 adulter+y
# adulthood            a+dulthood                adulthoo+d
# adults               a+dults                   adult+s
# advance              a+dvance                  advanc+e
# advancement          a+dvancement              advancemen+t
# advancements         a+dvancements             advancement+s
# advances             a+dvances                 advance+s
# advantage            a+dvantage                advantag+e
# advantages           a+dvantages               advantage+s
# advent               a+dvent                   adven+t
# adventure            a+dventure                adventur+e
# adventurers          a+dventurers              adventurer+s
# adventures           a+dventures               adventure+s
# adverb               a+dverb                   adver+b
# adverbs              a+dverbs                  adverb+s
# adversaries          a+dversaries              adversarie+s
# adversary            a+dversary                adversar+y
# adversity            a+dversity                adversit+y
# advertisement        a+dvertisement            advertisemen+t
# advertisements       a+dvertisements           advertisement+s
# advertisers          a+dvertisers              advertiser+s
# advertising          a+dvertising              advertisin+g
# advice               a+dvice                   advic+e
# advisability         a+dvisability             advisabilit+y
# advisement           a+dvisement               advisemen+t
# adviser              a+dviser                  advise+r
# advisers             a+dvisers                 adviser+s
# advisor              a+dvisor                  adviso+r
# advisors             a+dvisors                 advisor+s
# advisory             a+dvisory                 advisor+y
# advocacy             a+dvocacy                 advocac+y
# advocate             a+dvocate                 advocat+e
# advocates            a+dvocates                advocate+s
# aec                  a+ec                      ae+c
# aegis                a+egis                    aegi+s
# aeon                 a+eon                     aeo+n
# aeration             a+eration                 aeratio+n
# aerator              a+erator                  aerato+r
# aerials              a+erials                  aerial+s
# aerosol              a+erosol                  aeroso+l
# aerosols             a+erosols                 aerosol+s
# aesthetes            a+esthetes                aesthete+s
# aesthetic            a+esthetic                aestheti+c
# aesthetics           a+esthetics               aesthetic+s
# affair               a+ffair                   affai+r
# affairs              a+ffairs                  affair+s
# affect               a+ffect                   affec+t
# affectation          a+ffectation              affectatio+n
# affection            a+ffection                affectio+n
# affections           a+ffections               affection+s
# affects              a+ffects                  affect+s
# affidavits           a+ffidavits               affidavit+s
# affiliates           a+ffiliates               affiliate+s
# affiliation          a+ffiliation              affiliatio+n
# affiliations         a+ffiliations             affiliation+s
# affinities           a+ffinities               affinitie+s
# affinity             a+ffinity                 affinit+y
# affirmation          a+ffirmation              affirmatio+n
# affirmations         a+ffirmations             affirmation+s
# affliction           a+ffliction               afflictio+n
# afflictions          a+fflictions              affliction+s
# affluence            a+ffluence                affluenc+e
# affront              a+ffront                  affron+t
# afghan               a+fghan                   afgha+n
# aficionado           a+ficionado               aficionad+o
# aftermath            a+ftermath                aftermat+h
# afternoon            a+fternoon                afternoo+n
# afternoons           a+fternoons               afternoon+s
# agates               a+gates                   agate+s
# age                  a+ge                      ag+e
# agencies             a+gencies                 agencie+s
# agency               a+gency                   agenc+y
# agenda               a+genda                   agend+a
# agent                a+gent                    agen+t
# agents               a+gents                   agent+s
# ages                 a+ges                     age+s
# agglomeration        a+gglomeration            agglomeratio+n
# agglutination        a+gglutination            agglutinatio+n
# agglutinin           a+gglutinin               agglutini+n
# agglutinins          a+gglutinins              agglutinin+s
# aggregate            a+ggregate                aggregat+e
# aggregation          a+ggregation              aggregatio+n
# aggregations         a+ggregations             aggregation+s
# aggression           a+ggression               aggressio+n
# aggressions          a+ggressions              aggression+s
# aggressiveness       a+ggressiveness           aggressivenes+s
# aggressor            a+ggressor                aggresso+r
# agility              a+gility                  agilit+y
# agitation            a+gitation                agitatio+n
# agitator             a+gitator                 agitato+r
# agitators            a+gitators                agitator+s
# agnomen              a+gnomen                  agnome+n
# agnostics            a+gnostics                agnostic+s
# agonies              a+gonies                  agonie+s
# agony                a+gony                    agon+y
# agrarian             a+grarian                 agraria+n
# agreeableness        a+greeableness            agreeablenes+s
# agreement            a+greement                agreemen+t
# agreements           a+greements               agreement+s
# agriculture          a+griculture              agricultur+e
# ague                 a+gue                     agu+e
# aia                  a+ia                      ai+a
# aiche                a+iche                    aich+e
# aid                  a+id                      ai+d
# aide                 a+ide                     aid+e
# aides                a+ides                    aide+s
# aids                 a+ids                     aid+s
# aiee                 a+iee                     aie+e
# ailerons             a+ilerons                 aileron+s
# ailment              a+ilment                  ailmen+t
# ailments             a+ilments                 ailment+s
# aim                  a+im                      ai+m
# aimo                 a+imo                     aim+o
# aims                 a+ims                     aim+s
# air                  a+ir                      ai+r
# aircraft             a+ircraft                 aircraf+t
# airdrops             a+irdrops                 airdrop+s
# airfield             a+irfield                 airfiel+d
# airfields            a+irfields                airfield+s
# airflow              a+irflow                  airflo+w
# airframe             a+irframe                 airfram+e
# airlift              a+irlift                  airlif+t
# airline              a+irline                  airlin+e
# airlines             a+irlines                 airline+s
# airlock              a+irlock                  airloc+k
# airmail              a+irmail                  airmai+l
# airmen               a+irmen                   airme+n
# airplane             a+irplane                 airplan+e
# airplanes            a+irplanes                airplane+s
# airport              a+irport                  airpor+t
# airports             a+irports                 airport+s
# airs                 a+irs                     air+s
# airspeed             a+irspeed                 airspee+d
# airstrip             a+irstrip                 airstri+p
# airstrips            a+irstrips                airstrip+s
# airways              a+irways                  airway+s
# aisle                a+isle                    aisl+e
# aja                  a+ja                      aj+a
# ajb                  a+jb                      aj+b
# aku                  a+ku                      ak+u
# alabaster            a+labaster                alabaste+r
# alarm                a+larm                    alar+m
# alarms               a+larms                   alarm+s
# album                a+lbum                    albu+m
# albumin              a+lbumin                  albumi+n
# albums               a+lbums                   album+s
# alchemy              a+lchemy                  alchem+y
# alcohol              a+lcohol                  alcoho+l
# alcoholics           a+lcoholics               alcoholic+s
# alcoholism           a+lcoholism               alcoholis+m
# alcohols             a+lcohols                 alcohol+s
# alcoves              a+lcoves                  alcove+s
# alderman             a+lderman                 alderma+n
# aldermen             a+ldermen                 alderme+n
# ale                  a+le                      al+e
# aleck                a+leck                    alec+k
# alert                a+lert                    aler+t
# alertness            a+lertness                alertnes+s
# alfresco             a+lfresco                 alfresc+o
# algae                a+lgae                    alga+e
# algaecide            a+lgaecide                algaecid+e
# algebra              a+lgebra                  algebr+a
# alginates            a+lginates                alginate+s
# algorithm            a+lgorithm                algorith+m
# alias                a+lias                    alia+s
# alibi                a+libi                    alib+i
# alibis               a+libis                   alibi+s
# alien                a+lien                    alie+n
# alienation           a+lienation               alienatio+n
# aliens               a+liens                   alien+s
# alignment            a+lignment                alignmen+t
# alignments           a+lignments               alignment+s
# alimony              a+limony                  alimon+y
# aliquots             a+liquots                 aliquot+s
# alizarin             a+lizarin                 alizari+n
# alkali               a+lkali                   alkal+i
# alkalis              a+lkalis                  alkali+s
# alkaloids            a+lkaloids                alkaloid+s
# alkylbenzenesulfonates a+lkylbenzenesulfonates   alkylbenzenesulfonate+s
# allay                a+llay                    alla+y
# allegations          a+llegations              allegation+s
# allegiance           a+llegiance               allegianc+e
# allegiances          a+llegiances              allegiance+s
# allegory             a+llegory                 allegor+y
# allergies            a+llergies                allergie+s
# allergy              a+llergy                  allerg+y
# alleviation          a+lleviation              alleviatio+n
# alley                a+lley                    alle+y
# alleys               a+lleys                   alley+s
# alleyways            a+lleyways                alleyway+s
# alliance             a+lliance                 allianc+e
# alliances            a+lliances                alliance+s
# allies               a+llies                   allie+s
# alligator            a+lligator                alligato+r
# alliteration         a+lliteration             alliteratio+n
# allocation           a+llocation               allocatio+n
# allocations          a+llocations              allocation+s
# allotment            a+llotment                allotmen+t
# allotments           a+llotments               allotment+s
# allowance            a+llowance                allowanc+e
# allowances           a+llowances               allowance+s
# alloy                a+lloy                    allo+y
# alloys               a+lloys                   alloy+s
# allure               a+llure                   allur+e
# allurement           a+llurement               alluremen+t
# allusion             a+llusion                 allusio+n
# allusions            a+llusions                allusion+s
# allusiveness         a+llusiveness             allusivenes+s
# ally                 a+lly                     all+y
# almond               a+lmond                   almon+d
# almonds              a+lmonds                  almond+s
# aloes                a+loes                    aloe+s
# aloneness            a+loneness                alonenes+s
# aloofness            a+loofness                aloofnes+s
# alphabet             a+lphabet                 alphabe+t
# altar                a+ltar                    alta+r
# alteration           a+lteration               alteratio+n
# alterations          a+lterations              alteration+s
# altercation          a+ltercation              altercatio+n
# alternate            a+lternate                alternat+e
# alternation          a+lternation              alternatio+n
# alternative          a+lternative              alternativ+e
# alternatives         a+lternatives             alternative+s
# altitude             a+ltitude                 altitud+e
# alto                 a+lto                     alt+o
# altruism             a+ltruism                 altruis+m
# alum                 a+lum                     alu+m
# aluminum             a+luminum                 aluminu+m
# alumnae              a+lumnae                  alumna+e
# alumni               a+lumni                   alumn+i
# alundum              a+lundum                  alundu+m
# alveoli              a+lveoli                  alveol+i
# alveolus             a+lveolus                 alveolu+s
# amalgamation         a+malgamation             amalgamatio+n
# amanuensis           a+manuensis               amanuensi+s
# amassing             a+massing                 amassin+g
# amateur              a+mateur                  amateu+r
# amateurishness       a+mateurishness           amateurishnes+s
# amateurs             a+mateurs                 amateur+s
# amazement            a+mazement                amazemen+t
# amazons              a+mazons                  amazon+s
# ambassador           a+mbassador               ambassado+r
# ambassadors          a+mbassadors              ambassador+s
# ambiance             a+mbiance                 ambianc+e
# ambiguities          a+mbiguities              ambiguitie+s
# ambiguity            a+mbiguity                ambiguit+y
# ambition             a+mbition                 ambitio+n
# ambitions            a+mbitions                ambition+s
# ambivalence          a+mbivalence              ambivalenc+e
# ambulance            a+mbulance                ambulanc+e
# ambulances           a+mbulances               ambulance+s
# ambuscade            a+mbuscade                ambuscad+e
# ambush               a+mbush                   ambus+h
# ambushes             a+mbushes                 ambushe+s
# amendment            a+mendment                amendmen+t
# amendments           a+mendments               amendment+s
# amethystine          a+methystine              amethystin+e
# amide                a+mide                    amid+e
# amines               a+mines                   amine+s
# amino                a+mino                    amin+o
# amity                a+mity                    amit+y
# ammo                 a+mmo                     amm+o
# ammonium             a+mmonium                 ammoniu+m
# ammunition           a+mmunition               ammunitio+n
# amorality            a+morality                amoralit+y
# amorist              a+morist                  amoris+t
# amortization         a+mortization             amortizatio+n
# amount               a+mount                   amoun+t
# amounts              a+mounts                  amount+s
# amp                  a+mp                      am+p
# amphetamines         a+mphetamines             amphetamine+s
# amphibology          a+mphibology              amphibolog+y
# amphitheater         a+mphitheater             amphitheate+r
# amplification        a+mplification            amplificatio+n
# amplifier            a+mplifier                amplifie+r
# amplifiers           a+mplifiers               amplifier+s
# amplitude            a+mplitude                amplitud+e
# amulet               a+mulet                   amule+t
# amulets              a+mulets                  amulet+s
# amusement            a+musement                amusemen+t
# amusements           a+musements               amusement+s
# anachronism          a+nachronism              anachronis+m
# anachronisms         a+nachronisms             anachronism+s
# anaconda             a+naconda                 anacond+a
# anacondas            a+nacondas                anaconda+s
# anaesthesia          a+naesthesia              anaesthesi+a
# anagram              a+nagram                  anagra+m
# analogies            a+nalogies                analogie+s
# analogue             a+nalogue                 analogu+e
# analogues            a+nalogues                analogue+s
# analogy              a+nalogy                  analog+y
# analyses             a+nalyses                 analyse+s
# analysis             a+nalysis                 analysi+s
# analyst              a+nalyst                  analys+t
# analysts             a+nalysts                 analyst+s
# analyticity          a+nalyticity              analyticit+y
# anaplasmosis         a+naplasmosis             anaplasmosi+s
# anaprapath           a+naprapath               anaprapat+h
# anarchist            a+narchist                anarchis+t
# anarchy              a+narchy                  anarch+y
# anastomoses          a+nastomoses              anastomose+s
# anastomosis          a+nastomosis              anastomosi+s
# anatomical           a+natomical               anatomica+l
# anatomicals          a+natomicals              anatomical+s
# anatomy              a+natomy                  anatom+y
# ancestor             a+ncestor                 ancesto+r
# ancestors            a+ncestors                ancestor+s
# ancestry             a+ncestry                 ancestr+y
# anchor               a+nchor                   ancho+r
# anchorage            a+nchorage                anchorag+e
# anchoritism          a+nchoritism              anchoritis+m
# anchors              a+nchors                  anchor+s
# anchovy              a+nchovy                  anchov+y
# ancient              a+ncient                  ancien+t
# ancients             a+ncients                 ancient+s
# andrena              a+ndrena                  andren+a
# andrenas             a+ndrenas                 andrena+s
# anecdote             a+necdote                 anecdot+e
# anecdotes            a+necdotes                anecdote+s
# anemia               a+nemia                   anemi+a
# anesthetic           a+nesthetic               anestheti+c
# anesthetics          a+nesthetics              anesthetic+s
# angel                a+ngel                    ange+l
# angelica             a+ngelica                 angelic+a
# angels               a+ngels                   angel+s
# anger                a+nger                    ange+r
# angle                a+ngle                    angl+e
# angles               a+ngles                   angle+s
# anglophilia          a+nglophilia              anglophili+a
# anglophobia          a+nglophobia              anglophobi+a
# anguish              a+nguish                  anguis+h
# aniline              a+niline                  anilin+e
# animal               a+nimal                   anima+l
# animals              a+nimals                  animal+s
# animation            a+nimation                animatio+n
# animism              a+nimism                  animis+m
# animosity            a+nimosity                animosit+y
# anion                a+nion                    anio+n
# anionics             a+nionics                 anionic+s
# anions               a+nions                   anion+s
# anise                a+nise                    anis+e
# anisotropy           a+nisotropy               anisotrop+y
# ankle                a+nkle                    ankl+e
# ankles               a+nkles                   ankle+s
# annals               a+nnals                   annal+s
# annihilation         a+nnihilation             annihilatio+n
# anniversaries        a+nniversaries            anniversarie+s
# anniversary          a+nniversary              anniversar+y
# announcement         a+nnouncement             announcemen+t
# announcements        a+nnouncements            announcement+s
# announcer            a+nnouncer                announce+r
# announcers           a+nnouncers               announcer+s
# annoyance            a+nnoyance                annoyanc+e
# annoyances           a+nnoyances               annoyance+s
# annual               a+nnual                   annua+l
# annum                a+nnum                    annu+m
# anode                a+node                    anod+e
# anodes               a+nodes                   anode+s
# anomalies            a+nomalies                anomalie+s
# anomaly              a+nomaly                  anomal+y
# anomie               a+nomie                   anomi+e
# anonymity            a+nonymity                anonymit+y
# anorexia             a+norexia                 anorexi+a
# answer               a+nswer                   answe+r
# answers              a+nswers                  answer+s
# ant                  a+nt                      an+t
# antagonism           a+ntagonism               antagonis+m
# antagonisms          a+ntagonisms              antagonism+s
# antagonist           a+ntagonist               antagonis+t
# antagonists          a+ntagonists              antagonist+s
# ante                 a+nte                     ant+e
# anteater             a+nteater                 anteate+r
# antecedent           a+ntecedent               anteceden+t
# antecedents          a+ntecedents              antecedent+s
# antelope             a+ntelope                 antelop+e
# antenna              a+ntenna                  antenn+a
# antennae             a+ntennae                 antenna+e
# antennas             a+ntennas                 antenna+s
# anteriors            a+nteriors                anterior+s
# anthems              a+nthems                  anthem+s
# anthology            a+nthology                antholog+y
# anthropologist       a+nthropologist           anthropologis+t
# anthropologists      a+nthropologists          anthropologist+s
# anthropology         a+nthropology             anthropolog+y
# antibiotic           a+ntibiotic               antibioti+c
# antibiotics          a+ntibiotics              antibiotic+s
# antibodies           a+ntibodies               antibodie+s
# antibody             a+ntibody                 antibod+y
# anticipation         a+nticipation             anticipatio+n
# anticipations        a+nticipations            anticipation+s
# anticoagulation      a+nticoagulation          anticoagulatio+n
# antics               a+ntics                   antic+s
# antidote             a+ntidote                 antidot+e
# antifundamentalist   a+ntifundamentalist       antifundamentalis+t
# antigen              a+ntigen                  antige+n
# antipathy            a+ntipathy                antipath+y
# antipodes            a+ntipodes                antipode+s
# antiquarians         a+ntiquarians             antiquarian+s
# antique              a+ntique                  antiqu+e
# antiques             a+ntiques                 antique+s
# antiquities          a+ntiquities              antiquitie+s
# antiquity            a+ntiquity                antiquit+y
# antiredeposition     a+ntiredeposition         antiredepositio+n
# antiseptic           a+ntiseptic               antisepti+c
# antisera             a+ntisera                 antiser+a
# antiserum            a+ntiserum                antiseru+m
# antithesis           a+ntithesis               antithesi+s
# ants                 a+nts                     ant+s
# anvil                a+nvil                    anvi+l
# anxieties            a+nxieties                anxietie+s
# anxiety              a+nxiety                  anxiet+y
# aorta                a+orta                    aort+a
# apartheid            a+partheid                aparthei+d
# apartment            a+partment                apartmen+t
# apartments           a+partments               apartment+s
# apathy               a+pathy                   apath+y
# ape                  a+pe                      ap+e
# ...
# window               w+indow                   windo+w
# windowpanes          w+indowpanes              windowpane+s
# windows              w+indows                  window+s
# winds                w+inds                    wind+s
# windshield           w+indshield               windshiel+d
# windstorm            w+indstorm                windstor+m
# windup               w+indup                   windu+p
# wine                 w+ine                     win+e
# winehead             w+inehead                 winehea+d
# wines                w+ines                    wine+s
# wing                 w+ing                     win+g
# wingback             w+ingback                 wingbac+k
# wingman              w+ingman                  wingma+n
# wings                w+ings                    wing+s
# wink                 w+ink                     win+k
# winner               w+inner                   winne+r
# winners              w+inners                  winner+s
# winnings             w+innings                 winning+s
# winos                w+inos                    wino+s
# wins                 w+ins                     win+s
# winter               w+inter                   winte+r
# winters              w+inters                  winter+s
# wintertime           w+intertime               wintertim+e
# wire                 w+ire                     wir+e
# wires                w+ires                    wire+s
# wiring               w+iring                   wirin+g
# wisdom               w+isdom                   wisdo+m
# wisenheimer          w+isenheimer              wisenheime+r
# wish                 w+ish                     wis+h
# wishes               w+ishes                   wishe+s
# wisp                 w+isp                     wis+p
# wisps                w+isps                    wisp+s
# wit                  w+it                      wi+t
# witch                w+itch                    witc+h
# witches              w+itches                  witche+s
# withdrawal           w+ithdrawal               withdrawa+l
# withes               w+ithes                   withe+s
# withholding          w+ithholding              withholdin+g
# witness              w+itness                  witnes+s
# witnesses            w+itnesses                witnesse+s
# wits                 w+its                     wit+s
# wives                w+ives                    wive+s
# wizard               w+izard                   wizar+d
# wlib                 w+lib                     wli+b
# woe                  w+oe                      wo+e
# wohd                 w+ohd                     woh+d
# wolf                 w+olf                     wol+f
# wolves               w+olves                   wolve+s
# woman                w+oman                    woma+n
# womanhood            w+omanhood                womanhoo+d
# womb                 w+omb                     wom+b
# women                w+omen                    wome+n
# wonder               w+onder                   wonde+r
# wonderfulness        w+onderfulness            wonderfulnes+s
# wondering            w+ondering                wonderin+g
# wonders              w+onders                  wonder+s
# wood                 w+ood                     woo+d
# woodcarver           w+oodcarver               woodcarve+r
# woodcutters          w+oodcutters              woodcutter+s
# woodgraining         w+oodgraining             woodgrainin+g
# woodland             w+oodland                 woodlan+d
# woodpecker           w+oodpecker               woodpecke+r
# woods                w+oods                    wood+s
# woodshed             w+oodshed                 woodshe+d
# woodsmoke            w+oodsmoke                woodsmok+e
# woodwind             w+oodwind                 woodwin+d
# woodwork             w+oodwork                 woodwor+k
# wool                 w+ool                     woo+l
# woolen               w+oolen                   woole+n
# woolworkers          w+oolworkers              woolworker+s
# woomera              w+oomera                  woomer+a
# wooooosh             w+ooooosh                 wooooos+h
# word                 w+ord                     wor+d
# wording              w+ording                  wordin+g
# words                w+ords                    word+s
# work                 w+ork                     wor+k
# workbench            w+orkbench                workbenc+h
# workday              w+orkday                  workda+y
# worker               w+orker                   worke+r
# workers              w+orkers                  worker+s
# workingmen           w+orkingmen               workingme+n
# workings             w+orkings                 working+s
# workman              w+orkman                  workma+n
# workmanship          w+orkmanship              workmanshi+p
# workmen              w+orkmen                  workme+n
# workout              w+orkout                  workou+t
# workouts             w+orkouts                 workout+s
# workpiece            w+orkpiece                workpiec+e
# works                w+orks                    work+s
# worksheet            w+orksheet                workshee+t
# workshop             w+orkshop                 worksho+p
# workshops            w+orkshops                workshop+s
# worktable            w+orktable                worktabl+e
# world                w+orld                    worl+d
# worlds               w+orlds                   world+s
# worm                 w+orm                     wor+m
# worms                w+orms                    worm+s
# worries              w+orries                  worrie+s
# worry                w+orry                    worr+y
# worship              w+orship                  worshi+p
# worshippers          w+orshippers              worshipper+s
# worsted              w+orsted                  worste+d
# worth                w+orth                    wort+h
# worthlessness        w+orthlessness            worthlessnes+s
# wound                w+ound                    woun+d
# wounds               w+ounds                   wound+s
# wrack                w+rack                    wrac+k
# wrangler             w+rangler                 wrangle+r
# wrapper              w+rapper                  wrappe+r
# wrappers             w+rappers                 wrapper+s
# wrapping             w+rapping                 wrappin+g
# wraps                w+raps                    wrap+s
# wrath                w+rath                    wrat+h
# wreath               w+reath                   wreat+h
# wreaths              w+reaths                  wreath+s
# wreck                w+reck                    wrec+k
# wreckage             w+reckage                 wreckag+e
# wrenches             w+renches                 wrenche+s
# wrestles             w+restles                 wrestle+s
# wrestlings           w+restlings               wrestling+s
# wretch               w+retch                   wretc+h
# wretchedness         w+retchedness             wretchednes+s
# wrinkle              w+rinkle                  wrinkl+e
# wrinkles             w+rinkles                 wrinkle+s
# wrist                w+rist                    wris+t
# wrists               w+rists                   wrist+s
# wristwatch           w+ristwatch               wristwatc+h
# writ                 w+rit                     wri+t
# writer               w+riter                   write+r
# writers              w+riters                  writer+s
# writhing             w+rithing                 writhin+g
# writing              w+riting                  writin+g
# writings             w+ritings                 writing+s
# writs                w+rits                    writ+s
# wrong                w+rong                    wron+g
# wrongdoer            w+rongdoer                wrongdoe+r
# wrongdoing           w+rongdoing               wrongdoin+g
# wrongs               w+rongs                   wrong+s
# wtv                  w+tv                      wt+v
# wwrl                 w+wrl                     wwr+l
# xenon                x+enon                    xeno+n
# xenophobia           x+enophobia               xenophobi+a
# xrelease             x+release                 xreleas+e
# xreserve             x+reserve                 xreserv+e
# xxxx                 x+xxx                     xxx+x
# xylem                x+ylem                    xyle+m
# xylophones           x+ylophones               xylophone+s
# yacht                y+acht                    yach+t
# yachtel              y+achtel                  yachte+l
# yachtels             y+achtels                 yachtel+s
# yachters             y+achters                 yachter+s
# yachts               y+achts                   yacht+s
# yachtsman            y+achtsman                yachtsma+n
# yachtsmen            y+achtsmen                yachtsme+n
# yaks                 y+aks                     yak+s
# yank                 y+ank                     yan+k
# yard                 y+ard                     yar+d
# yardage              y+ardage                  yardag+e
# yards                y+ards                    yard+s
# yardstick            y+ardstick                yardstic+k
# yarn                 y+arn                     yar+n
# yarns                y+arns                    yarn+s
# yassuhs              y+assuhs                  yassuh+s
# yawl                 y+awl                     yaw+l
# yawn                 y+awn                     yaw+n
# yaws                 y+aws                     yaw+s
# yeah                 y+eah                     yea+h
# year                 y+ear                     yea+r
# yearbook             y+earbook                 yearboo+k
# yearning             y+earning                 yearnin+g
# yearnings            y+earnings                yearning+s
# years                y+ears                    year+s
# yeast                y+east                    yeas+t
# yeasts               y+easts                   yeast+s
# yell                 y+ell                     yel+l
# yelling              y+elling                  yellin+g
# yellow               y+ellow                   yello+w
# yelp                 y+elp                     yel+p
# yelps                y+elps                    yelp+s
# yen                  y+en                      ye+n
# yesteryear           y+esteryear               yesteryea+r
# yield                y+ield                    yiel+d
# yielding             y+ielding                 yieldin+g
# yields               y+ields                   yield+s
# yip                  y+ip                      yi+p
# ymca                 y+mca                     ymc+a
# yodel                y+odel                    yode+l
# yoga                 y+oga                     yog+a
# yoke                 y+oke                     yok+e
# yokel                y+okel                    yoke+l
# yokels               y+okels                   yokel+s
# yolk                 y+olk                     yol+k
# yore                 y+ore                     yor+e
# young                y+oung                    youn+g
# youngster            y+oungster                youngste+r
# youngsters           y+oungsters               youngster+s
# youth                y+outh                    yout+h
# youths               y+ouths                   youth+s
# yucca                y+ucca                    yucc+a
# yuse                 y+use                     yus+e
# yyyy                 y+yyy                     yyy+y
# zeal                 z+eal                     zea+l
# zealot               z+ealot                   zealo+t
# zebra                z+ebra                    zebr+a
# zenith               z+enith                   zenit+h
# zero                 z+ero                     zer+o
# zeros                z+eros                    zero+s
# zest                 z+est                     zes+t
# zinc                 z+inc                     zin+c
# zipper               z+ipper                   zippe+r
# zlotys               z+lotys                   zloty+s
# zombie               z+ombie                   zombi+e
# zombies              z+ombies                  zombie+s
# zone                 z+one                     zon+e
# zones                z+ones                    zone+s
# zoning               z+oning                   zonin+g
# zoo                  z+oo                      zo+o
# zoologist            z+oologist                zoologis+t
# zoology              z+oology                  zoolog+y

# %% [markdown]
# wiht probability measure

# %%
import collections
import math

# --- Trie Node and Base Class (No change) ---
class TrieNode:
    def __init__(self):
        self.children = collections.defaultdict(TrieNode)
        self.is_end_of_word = False
        self.count = 0

class Trie:
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word: str):
        node = self.root
        for char in word:
            node = node.children[char]
            node.count += 1
        node.is_end_of_word = True

    def _calculate_entropy(self, node: TrieNode) -> float:
        if not node.children or node.count == 0:
            return 0.0
        entropy = 0.0
        for child in node.children.values():
            probability = child.count / node.count
            if probability > 0:
                entropy -= probability * math.log2(probability)
        return entropy

    def find_stem_suffix(self, word: str) -> (str, str, float): # MODIFIED return type
        node = self.root
        best_split_point = 0
        max_score = -1.0

        for i, char in enumerate(word):
            if char not in node.children:
                return word, "", 0.0 # Return 0 score if not found
            node = node.children[char]
            
            is_potential_split = (len(node.children) > 1 or node.is_end_of_word)
            
            if is_potential_split and i < len(word) - 1:
                frequency = node.count
                entropy = self._calculate_entropy(node)
                score = frequency * (entropy + 1)
                if score > max_score:
                    max_score = score
                    best_split_point = i + 1
        
        if best_split_point == 0:
            return word, "", 0.0 # Return 0 score if no split

        stem = word[:best_split_point]
        suffix = word[best_split_point:]
        return stem, suffix, max_score # MODIFIED: Return the score

# --- PrefixTrie and SuffixTrie (Modified to handle score) ---
class PrefixTrie(Trie):
    def analyze_word(self, word: str):
        # Now returns stem, suffix, and the score
        return self.find_stem_suffix(word)

class SuffixTrie(Trie):
    def insert(self, word: str):
        super().insert(word[::-1])

    def analyze_word(self, word: str):
        reversed_word = word[::-1]
        rev_head, rev_tail, score = self.find_stem_suffix(reversed_word) # Capture score
        suffix = rev_head[::-1]
        stem = rev_tail[::-1]
        return stem, suffix, score # Pass score through

# --- Main Execution (Modified to print score) ---
def run_analysis_on_test_set():
    test_words = [
        "go", "goes", "do", "does", "kite", "kites", "bus", "buses",
        "city", "cities", "try", "tries", "car", "cars", "boy", "boys",
        "apple", "apples", "play", "playing", "player", "players"
    ]
    
    prefix_trie = PrefixTrie()
    suffix_trie = SuffixTrie()
    for word in test_words:
        prefix_trie.insert(word)
        suffix_trie.insert(word)

    print("--- Analysis with Score Displayed ---")
    print("Word".ljust(15), "PrefixTrie (Score)".ljust(25), "SuffixTrie (Score)".ljust(25))
    print("-" * 65)

    words_to_analyze = ["goes", "kites", "cities", "cars", "apples", "player", "players", "playing"]
    for word in sorted(list(set(words_to_analyze))):
        p_stem, p_suffix, p_score = prefix_trie.analyze_word(word)
        s_stem, s_suffix, s_score = suffix_trie.analyze_word(word)
        
        p_out = f"{p_stem}+{p_suffix}" if p_suffix else p_stem
        s_out = f"{s_stem}+{s_suffix}" if s_suffix else s_stem
        
        print(f"{word:<15} {p_out:<15} ({p_score:7.2f}) {s_out:<15} ({s_score:7.2f})")

if __name__ == "__main__":
    run_analysis_on_test_set()
# Out:
# --- Analysis with Score Displayed ---
# Word            PrefixTrie (Score)        SuffixTrie (Score)
# -----------------------------------------------------------------
# apples          apple+s         (   3.00) apple+s         (  27.40)
# cars            c+ars           (   8.00) car+s           (  27.40)
# cities          c+ities         (   8.00) citie+s         (  27.40)
# goes            go+es           (   3.00) goe+s           (  27.40)
# kites           kite+s          (   3.00) kite+s          (  27.40)
# player          play+er         (   8.00) playe+r         (   4.00)
# players         play+ers        (   8.00) player+s        (  27.40)
# playing         play+ing        (   8.00) +playing        (   0.00)
